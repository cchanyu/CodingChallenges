# %% [markdown]
# ### Adobe<br>
#
# ***
#
# <br>

# %% [markdown]
# **1.Tell us about how you've dealt with unexpected changes to deadlines or project scope.<br>**
#
# **2.Basic data structures, algorithms, and some networking questions<br>**
# N/A<br>
#
# **3.Deleting a node from linked list.<br>**
# You need to set the header to the next element<br>
#
# **4.Reversing the digits of a number.<br>**
#
#
# **5.You are given an array of integers. What is the fastest way to generate an array where every integer at an index in the array is the product of all numbers in the given array except the number at that given index?<br>**
#
# **6.Describe how you do software development and how you approach your craft<br>**
#
#
# **7.What are the different classes in the collection frameworks in Java?<br>**
#
#
# **8.What is concurrent hashmap and how does it work?<br>**
#
#
# **9.What happens when you type a URL in a browser.<br>**
# It goes through a DNS(Domain Name Systems), then returns the NS(name server) TLD<br>
# TLD server hosts directory of which addresses associate with which domain<br>
# TLD responses with resolver IP address<br>
#
# **10.Design a spell checker.<br>**
#
#
# **11.Level order traversal of a BT. Difference between Queue,add() and Queue,offer()<br>**
#
# **12.Object oriented design for a Connect 4 board game.<br>**
#
#
# **13.Given a binary tree, find the lowest common ancestor of two nodes.<br>**
#
# **14.Which technologies have you used and why?<br>**
#
# **15.What is RAII?<br>**
#
# **16.What's the difference between a hash tree and a hash map?<br>**
#
# **17.How do you implement a hash map?<br>**
#
#
# **18.Write a binary tree class and do a breadth first search.<br>**
#
# **19.How do you implement a semaphore with mutex?<br>**
#
# **20.How does a mobile app obtain data from a server?<br>**
#
#
# **21.Write a SQL query to get some attribute from a table<br>**
#
# **22.How to move and rotate a window from one state to another?<br>**
#
# **23.Find a string in an unsorted array of strings.<br>**
#
# **24.Search for a string in a sorted array of strings (in any language you choose).<br>**
#
# **25.Return the value of the item k away from the end of a linked list<br>**
#
# **26.Reverse a linked list<br>**
# To reverse a linked list, you need to go to the header<br>
# remove it and for next element, start pointing to its previous element<br>
# It can be tricky with edge cases<br>
#
# **27.Implement Google Docs<br>**
#
#
# **28.Find duplicates in an array (try various methods)<br>**
#
#
# **29.How many zeros in 100! (100 factorial)?<br>**
# factors of 2: 2, 4, 6, 8...<br>
# factors of 5: 5, 10, 15, 20...<br>
#
# = 20 + 4 + 0 + 0 + ... (since 125 is greater than 100)<br>
# = 24<br>
#
# **30.Retrieve minimum element of a stack in O(1)<br>**
#
#
# **31.Explain OOP concepts through a module of your project<br>**
